# %% [markdown]
# # 00 · Colab runner
# Clone the repo, install deps, add Kaggle credentials, and run the pipeline on a Colab GPU.
# Set **Runtime → Change runtime type → GPU** first.

# %% [markdown]
# ## 1. Clone the repo

# %%
# !git clone https://github.com/shekeraoleksandr/AI-NutriCoach.git
# %cd AI-NutriCoach

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -q -r requirements.txt
# On Colab you can swap FAISS to GPU: !pip install -q faiss-gpu

# %% [markdown]
# ## 3. Kaggle credentials (to download the dataset)
# Kaggle now issues a single-line **access token** (`~/.kaggle/access_token`); the old `kaggle.json` is under *Create Legacy API Key*. `kagglehub` supports both.

# %% [markdown]
# **Recommended — Colab Secret (no files):** left sidebar 🔑 → add secret `KAGGLE_API_TOKEN` = your access-token string, enable it for this notebook, then:

# %%
from google.colab import userdata
import os
os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_API_TOKEN')
print('token loaded')

# %% [markdown]
# **Alt — access_token file:**

# %%
import os
os.makedirs('/root/.kaggle', exist_ok=True)
open('/root/.kaggle/access_token','w').write('PASTE_YOUR_TOKEN_HERE')
# !chmod 600 /root/.kaggle/access_token

# %% [markdown]
# **Alt — legacy kaggle.json** (Kaggle → API → *Create Legacy API Key*):

# %%
# from google.colab import files; files.upload()   # choose kaggle.json
# import os; os.makedirs('/root/.kaggle', exist_ok=True)
# !cp kaggle.json /root/.kaggle/ && chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# ## 4. Import the project modules

# %%
import sys; sys.path.insert(0,'src')
from nutricoach import data, models_tabular, cvae, ingest, retriever, pairs, rag, evaluate
print('modules imported OK')

# %% [markdown]
# ## 5. Run
# Now open the numbered notebooks in order (**01 → 06**), or drive the src modules directly. Quick check that the dataset download works:

# %%
csv_path = data.download_raw()
df = data.load_clean(csv_path)
print(df.shape); df.head()
